# %% [markdown]
# # Welcome to Advent of Code for the Year 2025

# %% [markdown]
# ## aoc-1.1
# The Elves have good news and bad news.
#
# The good news is that they've discovered project management! This has given them the tools they need to prevent their usual Christmas emergency. For example, they now know that the North Pole decorations need to be finished soon so that other critical tasks can start on time.
#
# The bad news is that they've realized they have a different emergency: according to their resource planning, none of them have any time left to decorate the North Pole!
#
# To save Christmas, the Elves need you to finish decorating the North Pole by December 12th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You arrive at the secret entrance to the North Pole base ready to start decorating. Unfortunately, the password seems to have been changed, so you can't get in. A document taped to the wall helpfully explains:
#
# "Due to new security protocols, the password is locked in the safe below. Please see the attached document for the new combination."
#
# The safe has a dial with only an arrow on it; around the dial are the numbers 0 through 99 in order. As you turn the dial, it makes a small click noise as it reaches each number.
#
# The attached document (your puzzle input) contains a sequence of rotations, one per line, which tell you how to open the safe. A rotation starts with an L or R which indicates whether the rotation should be to the left (toward lower numbers) or to the right (toward higher numbers). Then, the rotation has a distance value which indicates how many clicks the dial should be rotated in that direction.
#
# So, if the dial were pointing at 11, a rotation of R8 would cause the dial to point at 19. After that, a rotation of L19 would cause it to point at 0.
#
# Because the dial is a circle, turning the dial left from 0 one click makes it point at 99. Similarly, turning the dial right from 99 one click makes it point at 0.
#
# So, if the dial were pointing at 5, a rotation of L10 would cause it to point at 95. After that, a rotation of R5 could cause it to point at 0.
#
# The dial starts by pointing at 50.
#
# You could follow the instructions, but your recent required official North Pole secret entrance security training seminar taught you that the safe is actually a decoy. The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.
#
# For example, suppose the attached document contained the following rotations:
#
# L68
# L30
# R48
# L5
# R60
# L55
# L1
# L99
# R14
# L82
# Following these rotations would cause the dial to move as follows:
#
# The dial starts by pointing at 50.
# The dial is rotated L68 to point at 82.
# The dial is rotated L30 to point at 52.
# The dial is rotated R48 to point at 0.
# The dial is rotated L5 to point at 95.
# The dial is rotated R60 to point at 55.
# The dial is rotated L55 to point at 0.
# The dial is rotated L1 to point at 99.
# The dial is rotated L99 to point at 0.
# The dial is rotated R14 to point at 14.
# The dial is rotated L82 to point at 32.
# Because the dial points at 0 a total of three times during this process, the password in this example is 3.
#
# Analyze the rotations in your attached document. What's the actual password to open the door?

# %% [markdown]
# ### Input

# %%
path = '/mnt/c/Users/guspa/Desktop/python_homework/data/aoc25/aoc25_1.1.txt'
mode = 'r'

move_side = []
move_num = []

with open(path, mode) as file:
    for line in file.readlines():
        line = line.strip()

        move_side.append(line[0])

        move_num.append(line[1:])

print(move_side)
print(move_num)
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'R', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'L', 'R
# ...

# %% [markdown]
# ### Functions

# %%
# closing a loop 0-99-0
def ouroboros(integer):
    if integer >= 100:
            integer = integer - 100
        
    elif integer < 0:
        integer = integer + 100

    else:
        integer = integer

    return integer

print('test:', ouroboros(123))
# Out:
# test: 23

# %%
# accounting for higher number than 99
def extreme_moves(integer):
    if integer >= 100:
        integer = integer % 100
    else:
        integer = integer
    
    return integer

print('test:', extreme_moves(456))
# Out:
# test: 56

# %% [markdown]
# ### Programme

# %%
password = 0
position = 50

for turn in range(len(move_num)):

    move = extreme_moves(int(move_num[turn]))

    if move_side[turn] == 'L':
        position = position - move

        position = ouroboros(integer = position)

        print(position)

    else:
        position = position + move

        position = ouroboros(integer = position)
        
        print(position)

    if position == 0:
        password += 1
# Out:
# 30
# 17
# 1
# 85
# 56
# 49
# 1
# 53
# 22
# 49
# 25
# 21
# 87
# 46
# 36
# 42
# 85
# 14
# 39
# 43
# 30
# 37
# 46
# 4
# 46
# 30
# 11
# 0
# 92
# 95
# 97
# 14
# 23
# 64
# 6
# 92
# 88
# 10
# 91
# 42
# 13
# 36
# 56
# 43
# 25
# 19
# 79
# 64
# 9
# 43
# 98
# 61
# 52
# 23
# 0
# 42
# 14
# 17
# 0
# 79
# 72
# 6
# 47
# 90
# 41
# 92
# 0
# 57
# 0
# 54
# 0
# 49
# 80
# 24
# 29
# 0
# 80
# 5
# 25
# 67
# 0
# 74
# 62
# 32
# 69
# 0
# 75
# 58
# 0
# 36
# 84
# 17
# 61
# 0
# 11
# 44
# 53
# 0
# 66
# 5
# 0
# 92
# 42
# 50
# 0
# 65
# 0
# 59
# 49
# 85
# 41
# 98
# 0
# 57
# 58
# 0
# 38
# 0
# 4
# 0
# 21
# 0
# 65
# 0
# 1
# 0
# 34
# 52
# 8
# 0
# 31
# 23
# 44
# 0
# 35
# 27
# 0
# 52
# 12
# 23
# 58
# 0
# 77
# 45
# 21
# 70
# 0
# 74
# 6
# 35
# 15
# 84
# 0
# 7
# 97
# 71
# 0
# 87
# 0
# 79
# 15
# 0
# 94
# 0
# 55
# 42
# 73
# 63
# 75
# 36
# 28
# 87
# 0
# 86
# 36
# 0
# 23
# 56
# 60
# 48
# 60
# 83
# 70
# 0
# 74
# 0
# 77
# 78
# 0
# 25
# 81
# 1
# 20
# 0
# 22
# 0
# 1
# 0
# 19
# 69
# 20
# 16
# 77
# 18
# 56
# 27
# 68
# 26
# 51
# 0
# 33
# ...

# %% [markdown]
# ### Evaluation of Results

# %%
if password == 0:
    print('There is no decoded password.')
else:
    print('Password:', password)
# Out:
# Password: 1182

# %% [markdown]
# ### Deconstruction of the Example

# %%
# we need:
# move  | position
# 0     | 50
# L68   | 82
# L30   | 52
# R48   | 0
# L5    | 95
# R60   | 55
# L55   | 0
# L1    | 99
# L99   | 0
# R14   | 14
# L82   | 32
# R123  | 55

# password : 3

# what we have:
# input sequence of moves as strings in a list - numbers
move_num = ['68', '30', '48', '5', '60', '55', '1', '99', '14', '82', '123']
# input sequence of moves as strings in a list - sides
move_side = ['L', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'R']
# accumulator variable for password
password = 0
# starting position
position = 50

# for each turn in range of length of move_num sequence (11), do
for turn in range(len(move_num)):

    # if integer at index position (0) of move_num sequence (68) is larger or equal to 100, do
    if int(move_num[turn]) >= 100:
        # move becomes remainig of integer at index position of move_num sequence divided by 100
        move = int(move_num[turn]) % 100
    # otherwise, do
    else:
        # move becomes remainig of integer at index position of move_num sequence (68)
        move = int(move_num[turn])

    # if value at index position (0) of move_side sequence (L) is L, do
    if move_side[turn] == 'L':
        # position becomes a result of subtraction of move (68) from position (50)
        position = position - move
        # if position is larger or equal to 100, do
        if position >= 100:
            # position becomes a result of subtraction of 100 from position
            position = position - 100
        # else if position is smaller than 0, do
        elif position < 0:
            # position becomes a result of addition of 100 to position (-18)
            position = position + 100
        # otherwise, do
        else:
            #position becomes position
            position = position
        # debugging
        print(position)
    # otherwise, do
    else:
        # position becomes a result of addition of move to position
        position = position + move
        # if position is larger or equal to 100, do
        if position >= 100:
            # position becomes a result of subtraction of 100 from position
            position = position - 100
        # else if position is smaller than 0, do
        elif position < 0:
            # position becomes a result of addition of 100 to position (-18)
            position = position + 100
        # otherwise, do
        else:
            #position becomes position
            position = position
        # debugging
        print(position)

    # if position is 0, do
    if position == 0:
        # add 1 to password
        password += 1

# if password is 0, do
if password == 0:
    # print option with no password
    print('There is no decoded password.')
# otherwise, do
else:
    # print option with password
    print('Password:', password)
# Out:
# 82
# 52
# 0
# 95
# 55
# 0
# 99
# 0
# 14
# 32
# 55
# Password: 3

# %% [markdown]
# ## aoc25-1.2
# You're sure that's the right password, but the door won't open. You knock, but nobody answers. You build a snowman while you think.
#
# As you're rolling the snowballs for your snowman, you find another security document that must have fallen into the snow:
#
# "Due to newer security protocols, please use password method 0x434C49434B until further notice."
#
# You remember from the training seminar that "method 0x434C49434B" means you're actually supposed to count the number of times any click causes the dial to point at 0, regardless of whether it happens during a rotation or at the end of one.
#
# Following the same rotations as in the above example, the dial points at zero a few extra times during its rotations:
#
# The dial starts by pointing at 50.
# The dial is rotated L68 to point at 82; during this rotation, it points at 0 once.
# The dial is rotated L30 to point at 52.
# The dial is rotated R48 to point at 0.
# The dial is rotated L5 to point at 95.
# The dial is rotated R60 to point at 55; during this rotation, it points at 0 once.
# The dial is rotated L55 to point at 0.
# The dial is rotated L1 to point at 99.
# The dial is rotated L99 to point at 0.
# The dial is rotated R14 to point at 14.
# The dial is rotated L82 to point at 32; during this rotation, it points at 0 once.
# In this example, the dial points at 0 three times at the end of a rotation, plus three more times during a rotation. So, in this example, the new password would be 6.
#
# Be careful: if the dial were pointing at 50, a single rotation like R1000 would cause the dial to point at 0 ten times before returning back to 50!
#
# Using password method 0x434C49434B, what is the password to open the door?

# %% [markdown]
# ### Input

# %%
path = '/mnt/c/Users/guspa/Desktop/python_homework/data/aoc25/aoc25_1.1.txt'
mode = 'r'

move_side = []
move_num = []

with open(path, mode) as file:
    for line in file.readlines():
        line = line.strip()

        move_side.append(line[0])

        move_num.append(line[1:])

print(move_side)
print(move_num)
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'R', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'L', 'R
# ...

# %% [markdown]
# ### Deconstrucion

# %%
# we need:
# move  | position
# 0     | 50
# L68   | 82 - passed 0
# L30   | 52
# R48   | 0 - is 0
# L5    | 95
# R60   | 55 - passed 0
# L55   | 0 - is 0
# L1    | 99
# L99   | 0 - is 0
# R14   | 14 
# L82   | 32 - passed 0
# R123  | 55

# password : 3

# what we have:
# input sequence of moves as strings in a list - numbers
#original
#move_num = ['68', '30', '48', '5', '60', '55', '1', '99', '14', '82', '123']

# input sequence of moves as strings in a list - sides
move_side = ['L', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'R']
# accumulator variable for password
password = 0
# starting position
position = 50

print(position)
# for each turn in range of length of move_num sequence (11), do
for turn in range(len(move_num)):

    if position == 0:
        # if integer at index position (0) of move_num sequence (68) is larger or equal to 100, do
        if int(move_num[turn]) >= 100:
            # move becomes remainig of integer at index position of move_num sequence divided by 100
            move = int(move_num[turn]) % 100

            passing_zero = (int(move_num[turn]) // 100) - 1
            if passing_zero == 1:
                print('passed 0', passing_zero, 'time')
                password = password + passing_zero
                passing_zero = 0
            else:
                print('passed 0', passing_zero, 'times')
                password = password + passing_zero
                passing_zero = 0

        # otherwise, do
        else:
            # move becomes remainig of integer at index position of move_num sequence (68)
            move = int(move_num[turn])

        # if value at index position (0) of move_side sequence (L) is L, do
        if move_side[turn] == 'L':
            # position becomes a result of subtraction of move (68) from position (50)
            position = position - move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100
                
                #print(position)
                #print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                #print('passed 0 at move', move_side[turn] + move_num[turn])
                #password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position
                #print(position)
        # otherwise, do
        else:
            # position becomes a result of addition of move to position
            position = position + move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                #password += 1
                
            # otherwise, do
            else:
                #position becomes position
                position = position

        print(position)
    


    else:



        # if integer at index position (0) of move_num sequence (68) is larger or equal to 100, do
        if int(move_num[turn]) >= 100:
            # move becomes remainig of integer at index position of move_num sequence divided by 100
            move = int(move_num[turn]) % 100

            passing_zero = int(move_num[turn]) // 100
            if passing_zero == 1:
                print('passed 0', passing_zero, 'time')
                password = password + passing_zero
                passing_zero = 0
            else:
                print('passed 0', passing_zero, 'times')
                password = password + passing_zero
                passing_zero = 0

        # otherwise, do
        else:
            # move becomes remainig of integer at index position of move_num sequence (68)
            move = int(move_num[turn])

        # if value at index position (0) of move_side sequence (L) is L, do
        if move_side[turn] == 'L':
            # position becomes a result of subtraction of move (68) from position (50)
            position = position - move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position
                #print(position)
        # otherwise, do
        else:
            # position becomes a result of addition of move to position
            position = position + move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position

        print(position)

        # if position is 0, do
        if position == 0:
            # add 1 to password
            password += 1

# if password is 0, do
if password == 0:
    # print option with no password
    print('There is no decoded password.')
# otherwise, do
else:
    # print option with password
    print('Password:', password)
# Out:
# 50
# 30
# 17
# 33
# 17
# 46
# 39
# passed 0 at move L48
# 91
# 43
# 74
# 47
# 71
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[261], line 144
#     141     move = int(move_num[turn])
#     143 # if value at index position (0) of move_side sequence (L) is L, do
# --> 144 if move_side[turn] == 'L':
#     145     # position becomes a result of subtraction of move (68) from position (50)
#     146     position = position - move
#     147     # if position is larger or equal to 100, do
#
# IndexError: list index out of range

# %%
# we need:
# move  | position
# 0     | 50
# L68   | 82 - passed 0
# L30   | 52
# R48   | 0 - is 0
# L5    | 95
# R60   | 55 - passed 0
# L55   | 0 - is 0
# L1    | 99
# L99   | 0 - is 0
# R14   | 14 
# L82   | 32 - passed 0
# R123  | 55

# %% [markdown]
# b

# %%
# we need:
# move  | position
# 0     | 50
# L68   | 82 - passed 0
# L30   | 52
# R48   | 0 - is 0
# L5    | 95
# R60   | 55 - passed 0
# L55   | 0 - is 0
# L1    | 99
# L99   | 0 - is 0
# R14   | 14 
# L82   | 32 - passed 0
# R123  | 55
# L355  |

# password : 6

# what we have:
# input sequence of moves as strings in a list - numbers
#original
#move_num = ['68', '30', '48', '5', '60', '55', '1', '99', '14', '82', '123', '355']

# input sequence of moves as strings in a list - sides
#move_side = ['L', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'R', 'L']
# accumulator variable for password
password = 0
# starting position
position = 50

print(position)
# for each turn in range of length of move_num sequence (11), do
for turn in range(len(move_num)):

    if position == 0:
        # if integer at index position (0) of move_num sequence (68) is larger or equal to 100, do
        if int(move_num[turn]) >= 100:
            # move becomes remainig of integer at index position of move_num sequence divided by 100
            move = int(move_num[turn]) % 100

            passing_zero = (int(move_num[turn]) // 100) - 1

            if passing_zero == 1:
                print('passed 0', passing_zero, 'time')
                password = password + passing_zero
                passing_zero = 0
            else:
                print('passed 0', passing_zero, 'times')
                password = password + passing_zero
                passing_zero = 0

        # otherwise, do
        else:
            # move becomes remainig of integer at index position of move_num sequence (68)
            move = int(move_num[turn])

        # if value at index position (0) of move_side sequence (L) is L, do
        if move_side[turn] == 'L':
            # position becomes a result of subtraction of move (68) from position (50)
            position = position - move
            # else if position is smaller than 0, do
            if position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                #password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position
                #print(position)
        # otherwise, do
        else:
            # position becomes a result of addition of move to position
            position = position + move

        print(position)
    


    else:

        # if integer at index position (0) of move_num sequence (68) is larger or equal to 100, do
        if int(move_num[turn]) >= 100:
            # move becomes remainig of integer at index position of move_num sequence divided by 100
            move = int(move_num[turn]) % 100

            passing_zero = int(move_num[turn]) // 100
            if passing_zero == 1:
                print('passed 0', passing_zero, 'time')
                password = password + passing_zero
                passing_zero = 0
            else:
                print('passed 0', passing_zero, 'times')
                password = password + passing_zero
                passing_zero = 0

        # otherwise, do
        else:
            # move becomes remainig of integer at index position of move_num sequence (68)
            move = int(move_num[turn])

        # if value at index position (0) of move_side sequence (L) is L, do
        if move_side[turn] == 'L':
            # position becomes a result of subtraction of move (68) from position (50)
            position = position - move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            elif position == 0:
                #position = position - 100
                #password -= 1

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position
                #print(position)

        # otherwise, do
        else:
            # position becomes a result of addition of move to position
            position = position + move
            # if position is larger or equal to 100, do
            if position > 100:
                # position becomes a result of subtraction of 100 from position
                position = position - 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            elif position == 100:
                position = position - 100

            # else if position is smaller than 0, do
            elif position < 0:
                # position becomes a result of addition of 100 to position (-18)
                position = position + 100

                #print(position)
                print('passed 0 at move', move_side[turn] + move_num[turn])
                password += 1

            # otherwise, do
            else:
                #position becomes position
                position = position

        print(position)

        # if position is 0, do
        if position == 0:
            # add 1 to password
            password += 1

# if password is 0, do
if password == 0:
    # print option with no password
    print('There is no decoded password.')
# otherwise, do
else:
    # print option with password
    print('Password:', password)
# Out:
#   Cell In[469], line 127
#     elif position < 0:
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 122

# %%
# we need:
# move  | position
# 0     | 50
# L68   | 82 - passed 0
# L30   | 52
# R48   | 0 - is 0
# L5    | 95
# R60   | 55 - passed 0
# L55   | 0 - is 0
# L1    | 99
# L99   | 0 - is 0
# R14   | 14 
# L82   | 32 - passed 0

# password : 6

# what we have:
#move_num = ['68', '30', '48', '5', '60', '55', '1', '99', '14', '82']
#move_side = ['L', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'L']

# special cases:
#move_num = ['50', '200', '211', '99']
#move_side = ['L', 'L', 'L', 'L']

# move  | position | password
#       | 50
# L50   | 0        | 1 - end
# L200  | 0        | 3 - passed 0 1x + end
# L211  | 89       | 5 - passed 0 2x
# L99   | 90       | 6- passed 0 1

'''
move: 1
passed 0: 2
0
Password: 4
move: 2
passed 0: 2
89
Password: 6
move: 3
90
Password: 7
'''

password = 0

position = 50
print(position)

for turn in range(len(move_num)):
    print('move:', turn)

    # IS STARTING AT 0?
    if position == 0:

        # IS MOVE EXTREME >= 100?
        if int(move_num[turn]) >= 100 and int(move_num[turn][len(move_num[turn])-1]) == 0: # and also ends 0 -1 from this counting

            passing_zero = (int(move_num[turn]) // 100) - 1
            print('passed 0:', passing_zero)
            password = password + passing_zero
            passing_zero = 0

            move = int(move_num[turn]) % 100

        elif int(move_num[turn]) >= 100 and int(move_num[turn][len(move_num[turn])-1]) != 0: # ends otehr that 0

            passing_zero = int(move_num[turn]) // 100
            print('here is the issue')
            print('passed 0:', passing_zero)
            password = password + passing_zero
            passing_zero = 0

            move = int(move_num[turn]) % 100
        
        # MOVE IS WITHIN 0-99
        else:
            move = int(move_num[turn])
        
        # IS MOVE L?
        if move_side[turn] == 'L':
            position = position - move

            if position < 0:
                position = position + 100

        # MOVE IS R
        else:
            position = position + move

    # STARTING AT 1-99
    else:

        # IS MOVE EXTREME >= 100?
        if int(move_num[turn]) >= 100:

            passing_zero = int(move_num[turn]) // 100
            print('passed 0:', passing_zero)
            password = password + passing_zero
            passing_zero = 0

            move = int(move_num[turn]) % 100
        
        # MOVE IS WITHIN 0-99
        else:
            move = int(move_num[turn])
        
        # IS MOVE L?
        if move_side[turn] == 'L':
            position = position - move

            if position < 0:
                position = position + 100
                password += 1

        # MOVE IS R
        else:
            position = position + move
        
            if position > 100:
                position = position - 100
                password += 1

            elif position == 100:
                position = position - 100

    # IF FINAL POSITION IS 0 ADD 1 
    print(position)
    if position == 0:
        password += 1

    # PASSWORD
    print('Password:', password)

# %% [markdown]
# ### VERSION 2

# %%
path = '/mnt/c/Users/guspa/Desktop/python_homework/data/aoc25/aoc25_1.2.txt'
mode = 'r'

move_side = []
move_num = []

with open(path, mode) as file:
    for line in file.readlines():
        line = line.strip()

        move_side.append(line[0])

        move_num.append(line[1:])

print(move_side)
print(move_num)
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'L', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'R', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'R', 'L', 'L', 'R
# ...

# %%
# accumulator variable for password
password = 0
# starting position
position = 50

# example
#move_num = ['68', '30', '48', '5', '60', '55', '1', '99', '14', '82']
#move_side = ['L', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'R', 'L']

# test
#move_num = ['250', '99', '1', '1', '1']
#move_side = ['R', 'R', 'R', 'R', 'L']

# for each turn in range of all moves, do
for turn in range(len(move_num)):

    # if it is L move, do
    if move_side[turn] == 'L':
        # for each click in range of move number, do
        for click in range(int(move_num[turn])):
            # subtract 1 from position
            position -= 1

            # if position is -1, do
            if position == -1:
                position = 99 # position becomes 99

            # if position is 0, do 
            if position == 0:
                password += 1 # add 1 to password

    # it is R move, do
    else:
        # for each click in range of move number, do
        for click in range(int(move_num[turn])):
            # add 1 to position
            position += 1

            # if position is 100, do           
            if position == 100:
                position = 0 # position becomes 0

            # if position is 0, do
            if position == 0:
                password += 1 # add 1 to password

# print password
print('password:', password) # right answer: 6907
# Out:
# password: 6907

# %% [markdown]
# ## aoc-2.1
# You get inside and take the elevator to its only other stop: the gift shop. "Thank you for visiting the North Pole!" gleefully exclaims a nearby sign. You aren't sure who is even allowed to visit the North Pole, but you know you can access the lobby through here, and from there you can access the rest of the North Pole base.
#
# As you make your way through the surprisingly extensive selection, one of the clerks recognizes you and asks for your help.
#
# As it turns out, one of the younger Elves was playing on a gift shop computer and managed to add a whole bunch of invalid product IDs to their gift shop database! Surely, it would be no trouble for you to identify the invalid product IDs for them, right?
#
# They've even checked most of the product ID ranges already; they only have a few product ID ranges (your puzzle input) that you'll need to check. For example:
#
# 11-22,95-115,998-1012,1188511880-1188511890,222220-222224,
# 1698522-1698528,446443-446449,38593856-38593862,565653-565659,
# 824824821-824824827,2121212118-2121212124
# (The ID ranges are wrapped here for legibility; in your input, they appear on a single long line.)
#
# The ranges are separated by commas (,); each range gives its first ID and last ID separated by a dash (-).
#
# Since the young Elf was just doing silly patterns, you can find the invalid IDs by looking for any ID which is made only of some sequence of digits repeated twice. So, 55 (5 twice), 6464 (64 twice), and 123123 (123 twice) would all be invalid IDs.
#
# None of the numbers have leading zeroes; 0101 isn't an ID at all. (101 is a valid ID that you would ignore.)
#
# Your job is to find all of the invalid IDs that appear in the given ranges. In the above example:
#
# 11-22 has two invalid IDs, 11 and 22.
# 95-115 has one invalid ID, 99.
# 998-1012 has one invalid ID, 1010.
# 1188511880-1188511890 has one invalid ID, 1188511885.
# 222220-222224 has one invalid ID, 222222.
# 1698522-1698528 contains no invalid IDs.
# 446443-446449 has one invalid ID, 446446.
# 38593856-38593862 has one invalid ID, 38593859.
# The rest of the ranges contain no invalid IDs.
# Adding up all the invalid IDs in this example produces 1227775554.
#
# What do you get if you add up all of the invalid IDs?

# %% [markdown]
# ###

# %% [markdown]
# ### Input

# %%
path = '/mnt/c/Users/guspa/Desktop/python_homework/data/aoc25/aoc25_2.1.txt'
mode = 'r'

database = []
item = ''

with open(path, mode) as file:
    for line in file.readlines():
        line = line.strip()
        
        for position in range(len(line)):

            if line[position]== ',':
                database.append(item)
                item = ''

            else:
                item += line[position]

print(database)
# Out:
# ['11-22', '95-115', '998-1012', '1188511880-1188511890', '222220-222224', '1698522-1698528', '446443-446449', '38593856-38593862', '565653-565659', '824824821-824824827']

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Programme

# %%
# example:

#database = ['11-22', '95-115', '998-1012', '1188511880-1188511890', '222220-222224', '1698522-1698528', '446443-446449', '38593856-38593862', '565653-565659', '824824821-824824827', '2121212118-2121212124']

invalid_ID = 0
ID_check = ''

for item in database:

    for character in item:
# Out:
# 11-22
# 95-115
# 998-1012
# 1188511880-1188511890
# 222220-222224
# 1698522-1698528
# 446443-446449
# 38593856-38593862
# 565653-565659
# 824824821-824824827
