# %% [markdown]
# # Experimenting with Python
#
# \<This notebook serves to learn python commands while working in a Jupyter Notebook and JupyterLab environment. Markdown cells and comments (#) serve for information and clarification, while the main purpose of the Python cells is to store commands.\>

# %% [markdown]
# ## 2025-11-03

# %%
print("Hello world!") # printing a string
# Out:
# Hello world!

# %%
3 * 4 # multiplication - one of mathematical operations
# Out:
# 12

# %%
7 + 10 # addition
# Out:
# 17

# %%
7 - 10 # subtraction
# Out:
# -3

# %%
10 / 3 # division
# Out:
# 3.3333333333333335

# %%
10 % 3 # division remainder
# Out:
# 1

# %%
10 // 3 # division rounded down
# Out:
# 3

# %%
2 ** 32 # exponentiation
# Out:
# 4294967296

# %%
2 ** 43000 # max limit for exponentiation reached, unless breached
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/carpentries/lib/python3.14/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/miniforge3/envs/carpentries/lib/python3.14/site-packages/IPython/lib/pretty.py:386, in RepresentationPrinter.pretty(self, obj)
#     383 for cls in _get_mro(obj_class):
#     384     if cls in self.type_pprinters:
# ...

# %%
"hello" + "world" # concatenation - merging multiple strings together into one unified
# Out:
# 'helloworld'

# %%
"hello"*8 # concatenation
# Out:
# 'hellohellohellohellohellohellohellohello'

# %%
8*"hello" # concatenation
# Out:
# 'hellohellohellohellohellohellohellohello'

# %%
(12**2 + 5**2)**0.5 # exponentiation and square root
# Out:
# 13.0

# %%
(12^2 + 5^2)^2 # bitwise exclusive OR operator
# Out:
# 11

# %%
4^7 # bitwise exclusive OR operator
# Out:
# 3

# %%
x = 3 # assigning a value to a variable

# %%
y = (10/7) # assigning a value to a variable

# %%
print(x , y) # printing a variable
# Out:
# 3 1.4285714285714286

# %%
x = (x + y) # assigning a value to a variable - repeated execution changes value of x

# %%
print(x) # printing a variable
# Out:
# 4.428571428571429

# %%
s = "the quick brown fox jumps over the lazy dog" # string of characters

# %%
s # quick-printing a variable
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
print(s) # printing a variable
# Out:
# the quick brown fox jumps over the lazy dog

# %%
s.upper() # all letter characters of the string of a variable will become upper case
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
s.title() # all first letter characters of the words of a variable will become upper case
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
s = s.capitalize() # assigning a value to a variable

# %%
s # quick-printing a variable
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s = s.lower() # all letter characters of a string will become lower case

# %%
s # quick-printing a variable
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s.lower().count("the") # combination of functions - string > lower case > count occurrence of "the" within the string
# Out:
# 2

# %%
s.count("the", ) # shift + tab for quick manual/options
# Out:
# 2

# %%
help(str) # manual for strings
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
s.split("h") # split the string using a chosen character/-s as a delimitter
# Out:
# ['t', 'e quick brown fox jumps over t', 'e lazy dog']

# %% [markdown]
# ## 2025-11-5

# %%
b = 4
print(type(b)) # int
# Out:
# <class 'int'>

# %%
a = 'num'
print(type(a)) #string
# Out:
# <class 'str'>

# %%
c = 2.5
print(type(c)) #float
# Out:
# <class 'float'>

# %%
print(type(5-3))
# Out:
# <class 'int'>

# %%
print(type('hello'-'h'))
# Out:
# <class 'str'>

# %%
print(type('hello'+'h'))

# %%
len(s) # text with a line break adds one more character, e.g.'\n'
# Out:
# 43

# %%
s[0:4] # [0,4) in mathematical style
# Out:
# 'the '

# %%
len(1992)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 len(1992)
#
# TypeError: object of type 'int' has no len()

# %%
len(str(1992)) # force casting
# Out:
# 4

# %%
some_number = '76.8' # does not work, because the number is a flaot
1 + int(some_number)
# Out:
# 77

# %%
len(str(10/3)) # displays finite number, then this result is turned into a string and then the string is counted for the number of characters
# Out:
# 18

# %%
test = print('blabla')
# Out:
# 3.3333333333333335

# %%
s = '...'
count_A = s.count('A')
count_C = s.count('C')
count_G = s.count('G')
count_T = s.count('T')

print(count_A, count_C, count_G, count_T)
# Out:
# 238 253 247 219

# %%
s = input('insert the DNA sequence: ')
DNA = [s.count('A'), s.count('C'), s.count('G'), s.count('T')]
print(DNA[0], DNA[1], DNA[2], DNA[3])
# Out:
# 20 12 17 21

# %%
a = 'flimsy'
b = 'miserable'
c = b[0:1] + a[2:]
print(c)
# Out:
# mimsy
