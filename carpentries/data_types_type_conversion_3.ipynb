# %% [markdown]
# # Data Types and Type Conversion

# %% [markdown]
# ## Exercises

# %%
# What type of a value is 3.4? How can you find out?
var = 3.4 
print(type(var)) # floating-point number
# Out:
# <class 'float'>

# %%
# What type of value is 3.25 + 4?
var = 3.25 + 4
print('it is a:', type(var)) # floating-point number
# Out:
# it is a: <class 'float'>

# %%
# If x = 5, what is the correct syntax for printing the data type of the variable x?
x = 5
print(type(x)) # as shown, type(value)
# Out:
# <class 'int'>

# %%
# What type of value (integer, floating point number, or character string) would you use to represent each of the following? Try to come up with more than one good answer for each problem. For example, in # 1, when would counting days with a floating point variable make more sense than using an integer?

# Number of days since the start of the year.
int, str
# Time elapsed from the start of the year until now in days.
float, str
# Serial number of a piece of lab equipment.
int, str
# A lab specimen’s age
float, str
# Current population of a city.
int, str
# Average population of a city over time.
float, str

# %%
# In Python 3, the // operator performs integer (whole-number) floor division, the / operator performs floating-point division, and the % (or modulo) operator calculates and returns the remainder from integer division.
print('5 // 3:', 5 // 3)
print('5 / 3:', 5 / 3)
print('5 % 3:', 5 % 3)

# If num_subjects is the number of subjects taking part in a study, and num_per_survey is the number that can take part in a single survey, write an expression that calculates the number of surveys needed to reach everyone once.
num_subjects = 13
num_per_survey = 3

num_surveys = num_subjects // num_per_survey # out of 22 people we can do only 4 surveys, one per 5 people, but we want to know how many surveys we need for a particular number of people

print(num_surveys)

num_surveys = (num_subjects - 1) // num_per_survey + 1

print(num_subjects, 'subjects,', num_per_survey, 'per survey:', num_surveys)
# Out:
# 4
# 13 subjects, 3 per survey: 5

# %%
# Where reasonable, float() will convert a string to a floating point number, and int() will convert a floating point number to an integer:
print("string to float:", float("3.4"))
print("float to int:", int(3.4))

# If the conversion doesn’t make sense, however, an error message will occur.
#print("string to float:", float("Hello world!"))

#Given this information, what do you expect the following program to do? What does it actually do? Why do you think it does that?
#print("fractional string to int:", int("3.4")) # I expect the program to convert the string of floating-point number to an integer; it actually results in an error; it seems that int function cannot transfer floating-point looking like string, perhaps it needs to be converted first to a float and then into an int
print("fractional string to int:", int(float("3.4")))
# Out:
# string to float: 3.4
# float to int: 3
# fractional string to int: 3

# %%
# Which of the following will return the floating point number 2.0? Note: there may be more than one right answer.
first = 1.0
second = "1"
third = "1.1"

#first + float(second); float(second) + float(third); first + int(third); first + int(float(third)); int(first) + int(float(third)); 2.0 * second
#answer: 1., 4.

first + float(second) # yes - 2.0
#float(second) + float(third) # no - 2.1
#first + int(third) #error - float before int
irst + int(float(third)) # yes - 2.0
#int(first) + int(float(third)) # no - 2
#2.0 * second # error - float cannot multiply string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 14
#       4 third = "1.1"
#       6 #first + float(second); float(second) + float(third); first + int(third); first + int(float(third)); int(first) + int(float(third)); 2.0 * second
#       7 #answer: 1., 4.
#       8
#    (...)     12 #irst + int(float(third)) # yes - 2.0
#      13 #int(first) + int(float(third)) # no - 2
# ---> 14 2.0 * second
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# Python provides complex numbers, which are written as 1.0+2.0j. If val is a complex number, its real and imaginary parts can be accessed using dot notation as val.real and val.imag.
a_complex_number = 6 + 2j
print(a_complex_number.real)
print(a_complex_number.imag)

# Why do you think Python uses j instead of i for the imaginary part? What do you expect 1 + 2j + 3 to produce? What do you expect 4j to be? What about 4 j or 4 + j?
# answer: 'j' acts probably as an unknown and it could be any letter; 4 + 2j; we would get 4 + 4j and 8 + j (but actually throws an error, since j is not associated with a number like an unknown and is treated as an undefined variable)
print(1 + 2j + 3)
print(1 + 4j + 3)
print(1 + 4 + j + 3)

# correction: Standard mathematics treatments typically use i to denote an imaginary number. However, from media reports it was an early convention established from electrical engineering that now presents a technically expensive area to change. For more information see: https://stackoverflow.com/questions/24812444/why-are-complex-numbers-in-python-denoted-with-j-instead-of-i
# Out:
# 6.0
# 2.0
# (4+2j)
# (4+4j)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 10
#       8 print(1 + 2j + 3)
#       9 print(1 + 4j + 3)
# ---> 10 print(1 + 4 + j + 3)
#
# NameError: name 'j' is not defined
